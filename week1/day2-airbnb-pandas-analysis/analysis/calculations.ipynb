# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/airbnb_clean.csv")
df.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     private room    149               1
# 1           Manhattan       Midtown  entire home/apt    225               1
# 2           Manhattan        Harlem     private room    150               3
# 3            Brooklyn  Clinton Hill  entire home/apt     89               1
# 4           Manhattan   East Harlem  entire home/apt     80              10
#
#    number_of_reviews last_review  reviews_per_month  \
# ...

# %% [raw]
# 🟦 ANALYSIS #1 — Avg Price Based on Neighbourhood Group

# %%
avg_price_neighbourhood_group = df.groupby("neighbourhood_group")["price"].mean().sort_values(ascending=False).reset_index()
avg_price_neighbourhood_group = avg_price_neighbourhood_group.rename(columns={"neighbourhood_group": "Neighbourhood Group", "price": "Avg Price"})
avg_price_neighbourhood_group
# Out:
#   Neighbourhood Group   Avg Price
# 0           Manhattan  165.260382
# 1            Brooklyn  115.350838
# 2       Staten Island   96.088235
# 3              Queens   95.538178
# 4               Bronx   85.881944

# %% [raw]
# 🟦 ANALYSIS #2 — Room Type by Occupancy Rate (Availability Analysis)

# %%
room_type_occupancy_rate = (1 - df.groupby("room_type")["availability_rate"].mean()).reset_index()
room_type_occupancy_rate
# Out:
#          room_type  availability_rate
# 0  entire home/apt           0.699905
# 1     private room           0.694468
# 2      shared room           0.574380

# %% [raw]
# 🟦 ANALYSIS #3 — Host Listings

# %%
host_listings = df.groupby(["host_id", "host_name"])["name"].count().sort_values(ascending=False).reset_index().rename(columns={"host_id": "ID", "host_name": "Host Name", "name": "Listing Counts"})
host_listings
# Out:
#               ID       Host Name  Listing Counts
# 0      219517861    Sonder (NYC)             317
# 1      107434423      Blueground             232
# 2       30283594            Kara             116
# 3       16098958  Jeremy & Laura              96
# 4       12243051          Sonder              96
# ...          ...             ...             ...
# 36342  274273284       Anastasia               1
# 36343  274298453          Adrien               1
# 36344  274307600        Jonathan               1
# 36345  274311461           Scott               1
# 36346   86182721        Jennifer               1
#
# [36347 rows x 3 columns]
